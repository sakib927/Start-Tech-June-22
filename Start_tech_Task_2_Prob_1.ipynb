# %% [markdown]
# <a href="https://colab.research.google.com/github/sakib927/Start-Tech-June-22/blob/main/Start_tech_Task_2_Prob_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 2
#
# Prablem Statement 1
#
# Your task is to help John from STA IT services to create a linear regression model in Python or R to predict the CTC/Salary of new hires from the data provided.

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import r2_score,mean_squared_error as mse 
from sklearn.linear_model import LinearRegression
from pandas_profiling import ProfileReport

# %% [markdown]
# Loading The Dataset

# %%
data = pd.read_excel('/content/drive/MyDrive/(Task1)Data_file.xlsx')

# %%
data_test = pd.read_csv('/content/drive/MyDrive/(Task 1)Test_data.xlsx.csv')

# %%
data
# Out:
#       S.No. College       Role  City type  Previous CTC  Previous job changes  \
# 0         1  Tier 1    Manager  Non-Metro         55523                     3
# 1         2  Tier 2  Executive      Metro         57081                     1
# 2         3  Tier 2  Executive      Metro         60347                     2
# 3         4  Tier 3  Executive      Metro         49010                     2
# 4         5  Tier 3  Executive      Metro         57879                     4
# ...     ...     ...        ...        ...           ...                   ...
# 1333   1334  Tier 3  Executive      Metro         59661                     4
# 1334   1335  Tier 1  Executive  Non-Metro         53714                     1
# 1335   1336  Tier 2  Executive  Non-Metro         61957                     1
# 1336   1337  Tier 1  Executive  Non-Metro         53203                     3
# 1337   1338  Tier 3    Manager  Non-Metro         51820                     1
#
# ...

# %%
#Printing the size of the dataset
data.size
# Out:
# 12042

# %%
#Printing the shape of the dataset
data.shape
# Out:
# (1338, 9)

# %%
# For information on Dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   S.No.                 1338 non-null   int64
#  1   College               1338 non-null   object
#  2   Role                  1338 non-null   object
#  3   City type             1338 non-null   object
#  4   Previous CTC          1338 non-null   int64
#  5   Previous job changes  1338 non-null   int64
#  6   Graduation marks      1338 non-null   int64
#  7   Exp (Months)          1338 non-null   int64
#  8   CTC                   1338 non-null   float64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 94.2+ KB

# %%
# Description Of the dataset
data.describe()
# Out:
#              S.No.  Previous CTC  Previous job changes  Graduation marks  \
# count  1338.000000   1338.000000           1338.000000       1338.000000
# mean    669.500000  55581.762332              2.525411         59.890882
# std     386.391641   6685.600553              1.123502         14.894696
# min       1.000000  36990.000000              1.000000         35.000000
# 25%     335.250000  50547.000000              2.000000         47.000000
# 50%     669.500000  55293.500000              3.000000         60.000000
# 75%    1003.750000  60150.500000              4.000000         73.000000
# max    1338.000000  77911.000000              4.000000         85.000000
#
#        Exp (Months)            CTC
# count   1338.000000    1338.000000
# mean      39.207025   75459.338993
# std       14.049960   12551.280263
# min       18.000000   53020.319026
# 25%       27.000000   66905.070033
# 50%       39.000000   73112.640487
# 75%       51.000000   80747.178420
# ...

# %%
# To Check Null values in Dataset 
data.isnull().sum()
# Out:
# S.No.                   0
# College                 0
# Role                    0
# City type               0
# Previous CTC            0
# Previous job changes    0
# Graduation marks        0
# Exp (Months)            0
# CTC                     0
# dtype: int64

# %%
#dropping S.No. column as S.no is not an critical info  
data.drop('S.No.',axis=1,inplace=True)

# %%
# Converting categorical data into numerical
data = pd.get_dummies(columns=['College','Role','City type'],drop_first=True,data=data)

# %%
#converting CTC into numerical
''''data['CTC'] = data['CTC'].str.replace(',', '')
data['Previous CTC'] = data['Previous CTC'].str.replace(',', '')
data['CTC'] = data['CTC'].astype('float')
data['Previous CTC'] = data['Previous CTC'].astype('float')'''
# Out:
# "'data['CTC'] = data['CTC'].str.replace(',', '')\ndata['Previous CTC'] = data['Previous CTC'].str.replace(',', '')\ndata['CTC'] = data['CTC'].astype('float')\ndata['Previous CTC'] = data['Previous CTC'].astype('float')"

# %%
X_train=data.drop('CTC',axis=1)
y_train=data[['CTC']]

# %%
model=LinearRegression(normalize=True)
model.fit(X_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
#checking test data
data_test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  ...  \
# 0           0         55523                     3                66  ...
# 1           1         57081                     1                84  ...
# 2           1         60347                     2                52  ...
# 3           1         49010                     2                81  ...
# 4           1         57879                     4                74  ...
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# ...

# %%
#Rearranging the test dataset columns
data_test = data_test[['College','Role','City type','previous CTC','previous job changes','Graduation marks','Exp','Actual CTC']]

# %%
#converting categorical data into numerical
data_test = pd.get_dummies(columns=['College','Role','City type'],drop_first=True,data=data_test)

# %%
X_test = data_test.drop('Actual CTC',axis=1)
y_test = data_test['Actual CTC']

# %%
#prediction with linear regression model
y_pred=model.predict(X_test)
print("R2 score",r2_score(y_test,y_pred))
print("MSE",mse(y_test,y_pred))
# Out:
# R2 score 0.6081873160460822
# MSE 61677937.04476757

# %%
#Predicated CTC
new_df=pd.DataFrame(y_pred,columns=["Predicated CTC"]).head()
final_df=pd.concat([data_test,new_df],axis=1).head()
final_df=final_df[['previous CTC','previous job changes','Graduation marks','Exp','College_Tier 2','College_Tier 3','Role_Manager','City type_Non-Metro','Actual CTC'	,'Predicated CTC']]
final_df
# Out:
#    previous CTC  previous job changes  Graduation marks  Exp  College_Tier 2  \
# 0         55523                     3                66   19               0
# 1         57081                     1                84   18               1
# 2         60347                     2                52   28               1
# 3         49010                     2                81   33               0
# 4         57879                     4                74   32               0
#
#    College_Tier 3  Role_Manager  City type_Non-Metro   Actual CTC  \
# 0               0             1                    1  71406.57653
# 1               0             0                    0  68005.87063
# 2               0             0                    0  76764.02028
# 3               1             0                    0  82092.38688
# 4               1             0                    0  73878.09773
#
#    Predicated CTC
# 0    86123.938140
# 1    65789.546527
# 2    69941.690302
# 3    66843.038384
# ...
